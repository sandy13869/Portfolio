# %%
# !pip install facebook-sdk

# %%
import os
import json
import facebook
from argparse import ArgumentParser

# %%
def get_parser():
    parser = ArgumentParser()
    parser.add_argument('--page')
    return parser

# %%
if __name__ == '__main__':
    parser = get_parser()
    args = parser.parse_args()
    
    tokem = os.environ.get('FACEBOOK_TEMP_TOKEN')
    fields = ['id','name','about','likes','website','link']
    fields = ','.join(fields)
    
    graph = facebook.GraphAPI(token)
    page = graph.get_object(args.page, field=fields)
    
    print(json.dumps(page, indent=4))
# Out:
# usage: ipykernel_launcher.py [-h] [--page PAGE]
# ipykernel_launcher.py: error: unrecognized arguments: -f /Users/rajusunkara/Library/Jupyter/runtime/kernel-1589662a-f5eb-42cf-af03-cb6334b14782.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /Users/rajusunkara/Documents/anakonda/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2971: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import facebook

# %%
graph = facebook.GraphAPI(access_token="zXxgZBtOvru49WnakgZD")

# %%
eng = graph.search(type='place', center='17.3850,78.4868',fields ='name,location')
eng
# Out:
# {'data': [{'name': 'Geethanjali College of Engineering and Technology',
#    'location': {'city': 'Hyderabad',
#     'country': 'India',
#     'latitude': 17.385044,
#     'longitude': 78.486671},
#    'id': '895394167183728'},
#   {'name': 'Koti',
#    'location': {'city': 'Hyderabad',
#     'country': 'India',
#     'latitude': 17.385259455934,
#     'longitude': 78.486611555565,
#     'street': 'Giriraj Lane',
#     'zip': '500001'},
#    'id': '1392468287531800'},
#   {'name': 'Hyderabad',
#    'location': {'city': 'Hyderabad',
#     'country': 'India',
#     'latitude': 17.395,
#     'longitude': 78.4676,
#     'zip': '500 xxx, 501 xxx, 502 xxx.'},
#    'id': '219901111354748'},
#   {'name': 'Haydrabaad',
#    'location': {'city': 'Hyderabad',
#     'country': 'India',
#     'latitude': 17.395,
#     'longitude': 78.4676,
#     'street': 'Prasanth nagar, Moulali, Hyderabad - 500040.'},
#    'id': '182094812436703'},
#   {'name': 'Old City (Hyderabad, India)',
# ...

# %%
name = []
street = []
for p in eng['data']:
    print(p['name'])
    sam.append(p['name'])
    print(p['location'])
    street.append(p['location'])
# Out:
# Geethanjali College of Engineering and Technology
# {'city': 'Hyderabad', 'country': 'India', 'latitude': 17.385044, 'longitude': 78.486671}
# Koti
# {'city': 'Hyderabad', 'country': 'India', 'latitude': 17.385259455934, 'longitude': 78.486611555565, 'street': 'Giriraj Lane', 'zip': '500001'}
# Hyderabad
# {'city': 'Hyderabad', 'country': 'India', 'latitude': 17.395, 'longitude': 78.4676, 'zip': '500 xxx, 501 xxx, 502 xxx.'}
# Haydrabaad
# {'city': 'Hyderabad', 'country': 'India', 'latitude': 17.395, 'longitude': 78.4676, 'street': 'Prasanth nagar, Moulali, Hyderabad - 500040.'}
# Old City (Hyderabad, India)
# {'city': 'Hyderabad', 'country': 'India', 'latitude': 17.366, 'longitude': 78.476}
# Narayanaguda, India
# {'city': 'Narayanaguda', 'country': 'India', 'latitude': 17.397374462336, 'longitude': 78.492464932881}
# Golconda Fort Hydrabad
# {'city': 'Hyderabad', 'country': 'India', 'latitude': 17.3824, 'longitude': 78.4819}
# Koti Womens College
# ...

# %%
street
# Out:
# [{'city': 'Hyderabad',
#   'country': 'India',
#   'latitude': 17.385044,
#   'longitude': 78.486671},
#  {'city': 'Hyderabad',
#   'country': 'India',
#   'latitude': 17.385259455934,
#   'longitude': 78.486611555565,
#   'street': 'Giriraj Lane',
#   'zip': '500001'},
#  {'city': 'Hyderabad',
#   'country': 'India',
#   'latitude': 17.395,
#   'longitude': 78.4676,
#   'zip': '500 xxx, 501 xxx, 502 xxx.'},
#  {'city': 'Hyderabad',
#   'country': 'India',
#   'latitude': 17.395,
#   'longitude': 78.4676,
#   'street': 'Prasanth nagar, Moulali, Hyderabad - 500040.'},
#  {'city': 'Hyderabad',
#   'country': 'India',
#   'latitude': 17.366,
#   'longitude': 78.476},
#  {'city': 'Narayanaguda',
#   'country': 'India',
#   'latitude': 17.397374462336,
#   'longitude': 78.492464932881},
#  {'city': 'Hyderabad',
#   'country': 'India',
#   'latitude': 17.3824,
#   'longitude': 78.4819},
#  {'city': 'Hyderabad',
#   'country': 'India',
#   'latitude': 17.38495,
#   'longitude': 78.48649,
# ...

# %%
len(sam)
# Out:
# 25
